# %%
import pandas as pd
import glob
import seaborn as sns
sns.set_style("whitegrid")
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_palette("summer")

# %%
filenames = glob.glob("*.csv")
main_log_name = "pomodone-log.csv"
if main_log_name in filenames:
    log = pd.read_csv(main_log_name, parse_dates=["started_date"])
else:
    temp_log = pd.read_csv(filename[0], parse_dates=[["started", "date"]])
    
for filename in filenames:
    if main_log_name != filename:
        print(main_log_name, filename)
        temp_log = pd.read_csv(filename, parse_dates=[["started", "date"]])
        log = pd.concat([log, temp_log], ignore_index=True).drop_duplicates()
log.set_index("started_date", inplace=True)
# Out:
# pomodone-log.csv pomodone-log-20190101-20200101-merge.csv
# pomodone-log.csv pomodone-log-20190501-20190609.csv
# /home/sriram/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if sys.path[0] == '':
# pomodone-log.csv pomodone-log-20190501-20190601.csv
# pomodone-log.csv pomodone-log-19691231-20180726-latest.csv
# pomodone-log.csv pomodone-log-19691231-20180629-early.csv
# pomodone-log.csv pomodone-log-20190601-20190701.csv

# %%
log
# Out:
#                      description  interruption notes     item id  log note  \
# started_date
# 2019-05-17 17:51:26          NaN                 NaN  3204075617       NaN
# 2019-05-17 18:36:28          NaN                 NaN  3204075617       NaN
# 2019-05-17 19:07:14          NaN                 NaN  3204075617       NaN
# 2019-05-17 19:50:03          NaN                 NaN  3204075617       NaN
# 2019-05-18 11:39:02          NaN                 NaN  3204075617       NaN
# 2019-05-18 12:13:11          NaN                 NaN  3204075617       NaN
# 2019-05-18 12:43:15          NaN                 NaN  3204075617       NaN
# 2019-05-18 14:07:42          NaN                 NaN  3204075617       NaN
# 2019-05-18 16:18:33          NaN                 NaN  3204075617       NaN
# 2019-05-18 16:49:19          NaN                 NaN  3204075617       NaN
# 2019-05-18 17:56:10          NaN                 NaN  3204075617       NaN
# ...

# %%
log.to_csv("pomodone-log.csv")
